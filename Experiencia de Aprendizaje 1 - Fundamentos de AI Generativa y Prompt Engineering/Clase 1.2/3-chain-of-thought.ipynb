# %% [markdown]
# # 3. Chain-of-Thought (CoT) Prompting - Razonamiento Paso a Paso
#
# ## Objetivos de Aprendizaje
# - Comprender el concepto de Chain-of-Thought (CoT) prompting
# - Implementar CoT con y sin ejemplos
# - Aplicar CoT a problemas complejos y razonamiento lógico
# - Combinar CoT con otras técnicas de prompting
#
# ## ¿Qué es Chain-of-Thought?
#
# Chain-of-Thought (CoT) es una técnica que hace que el modelo "**piense en voz alta**" mostrando su proceso de razonamiento paso a paso antes de llegar a la respuesta final.
#
# ### Principio Básico:
# En lugar de saltar directamente a la respuesta, el modelo:
# 1. **Descompone** el problema en pasos
# 2. **Razona** cada paso explícitamente
# 3. **Construye** hacia la solución final
# 4. **Proporciona** la respuesta con justificación
#
# ### Ventajas:
# - **Mejor precisión**: Especialmente en problemas complejos
# - **Transparencia**: Puedes ver el razonamiento
# - **Debugging**: Identificar dónde falla el razonamiento
# - **Confianza**: Mayor seguridad en la respuesta
#
# ### Casos de Uso Ideales:
# - Problemas matemáticos
# - Razonamiento lógico
# - Análisis complejos
# - Toma de decisiones
# - Resolución de problemas multi-paso

# %%
import os

os.environ["GITHUB_TOKEN"] = ""
os.environ["OPENAI_BASE_URL"] = ""
os.environ["GROQ_API_KEY"] = ""

# %%
# Configuración inicial
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
import os
import time

# Configurar el modelo
llm = ChatOpenAI(
    base_url=os.getenv("OPENAI_BASE_URL"),
    api_key=os.getenv("GITHUB_TOKEN"),
    model="gpt-4.1",
    temperature=0.1  # Baja temperatura para razonamiento más consistente
)

print("✓ Modelo configurado para Chain-of-Thought")
print("✓ Temperature baja para razonamiento consistente")
# Out:
# ✓ Modelo configurado para Chain-of-Thought
# ✓ Temperature baja para razonamiento consistente

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser
import json

# Initialize Groq LLM
llm = ChatGroq(
    api_key=os.getenv("GROQ_API_KEY"),
    model_name="llama-3.1-8b-instant",
    temperature=0.7
)

llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x00000253E0E7B6B0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000253E125E900>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %% [markdown]
# ## Comparación: Sin CoT vs Con CoT
#
# Veamos la diferencia dramática que puede hacer CoT en problemas complejos.

# %%
# Comparación directa: razonamiento directo vs CoT
def comparar_sin_vs_con_cot():
    print("=== COMPARACIÓN: SIN CoT vs CON CoT ===")
    
    # Problema complejo que requiere múltiples pasos
    problema = """Una tienda tiene una promoción: 'Compra 2 productos y obtén 30% de descuento en el más barato'. 
    Juan compra una camiseta de 45€, unos zapatos de 120€ y una chaqueta de 80€. 
    ¿Cuánto paga en total?"""
    
    # Prompt sin CoT
    prompt_sin_cot = f"""Resuelve este problema:
    
{problema}
    
Respuesta:"""
    
    # Prompt con CoT
    prompt_con_cot = f"""Resuelve este problema paso a paso:
    
{problema}
    
Piensa paso a paso:
1. Primero identifica los productos y precios
2. Determina cómo se aplica la promoción
3. Calcula el descuento
4. Calcula el total final
    
Razonamiento:"""
    
    # Probar sin CoT
    print("\n1. SIN CHAIN-OF-THOUGHT:")
    print("-" * 30)
    try:
        response_sin = llm.invoke([HumanMessage(content=prompt_sin_cot)])
        print(response_sin.content)
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n" + "="*60)
    
    # Probar con CoT
    print("\n2. CON CHAIN-OF-THOUGHT:")
    print("-" * 30)
    try:
        response_con = llm.invoke([HumanMessage(content=prompt_con_cot)])
        print(response_con.content)
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n=== ANÁLISIS ===")
    print("• Sin CoT: Puede llegar a respuesta incorrecta o saltar pasos")
    print("• Con CoT: Muestra razonamiento completo y reduce errores")
    print("• CoT especialmente útil para problemas multi-paso")

# Ejecutar comparación
comparar_sin_vs_con_cot()
# Out:
# === COMPARACIÓN: SIN CoT vs CON CoT ===
#
# 1. SIN CHAIN-OF-THOUGHT:
# ------------------------------
# Para resolver este problema, debemos seguir los siguientes pasos:
#
# 1. Primero, identificamos los tres productos que Juan compra: camiseta (45€), zapatos (120€) y chaqueta (80€).
# 2. Luego, debemos encontrar el producto más barato, que en este caso es la camiseta (45€).
# 3. Según la promoción, Juan obtiene un 30% de descuento en el producto más barato. Para calcular el descuento, multiplicamos el precio del producto más barato por 30% (0,30):
#    Descuento = 45€ x 0,30 = 13,50€
# 4. Luego, restamos el descuento al precio del producto más barato para encontrar el nuevo precio:
#    Nuevo precio del producto más barato = 45€ - 13,50€ = 31,50€
# 5. Ahora, sumamos los precios de los tres productos, pero aplicando el descuento en el producto más barato:
#    Total = Precio de la chaqueta + Precio de los zapatos + Nuevo precio del producto más barato
#          = 80€ + 120€ + 31,50€
#          = 231,50€
# 6. Por tanto, Juan paga un total de 231,50€ en la tienda.
#
# ============================================================
#
# 2. CON CHAIN-OF-THOUGHT:
# ------------------------------
# Resolveremos el problema paso a paso.
#
# **Paso 1: Identifica los productos y precios**
#
# - Camiseta: 45€
# - Zapatos: 120€
# - Chaqueta: 80€
#
# **Paso 2: Determina cómo se aplica la promoción**
#
# La promoción es 'Compra 2 productos y obtén 30% de descuento en el más barato'. Esto significa que Juan necesita comprar 2 productos para aplicar la promoción. En este caso, los 2 productos más baratos son la camiseta (45€) y la chaqueta (80€). El más barato de los 2 es la camiseta (45€).
#
# **Paso 3: Calcula el descuento**
#
# El precio de la camiseta es 45€ y el descuento es del 30%. Para calcular el descuento, multiplicamos el precio de la camiseta por el porcentaje de descuento:
#
# Descuento = 45€ x 30% = 45€ x 0,30 = 13,50€
#
# **Paso 4: Calcula el total final**
#
# Ahora que tenemos el descuento, restamos el descuento del precio original de la camiseta:
#
# Precio de la camiseta con descuento = 45€ - 13,50€ = 31,50€
#
# El total final es la suma de los precios de los 3 productos, menos el descuento de la camiseta:
#
# Total final = 120€ (zapatos) + 80€ (chaqueta) + 31,50€ (camiseta con descuento)
# Total final = 231,50€
#
# **Respuesta final**
#
# Juan paga un total de 231,50€.
#
# === ANÁLISIS ===
# • Sin CoT: Puede llegar a respuesta incorrecta o saltar pasos
# • Con CoT: Muestra razonamiento completo y reduce errores
# • CoT especialmente útil para problemas multi-paso

# %% [markdown]
# ## Zero-Shot Chain-of-Thought
#
# La forma más simple de CoT: simplemente pedirle al modelo que "piense paso a paso".

# %%
# Zero-shot CoT: solo agregar "piensa paso a paso"
def zero_shot_cot():
    print("=== ZERO-SHOT CHAIN-OF-THOUGHT ===")
    
    problemas = [
        "Si un tren viaja a 80 km/h y necesita llegar a una ciudad que está a 240 km, pero se detiene 15 minutos en una estación intermedia, ¿cuánto tiempo total toma el viaje?",
        "Una empresa tiene 150 empleados. El 40% trabaja en desarrollo, el 25% en ventas, el 20% en marketing y el resto en administración. Si cada empleado de desarrollo gana 50,000€ anuales, ¿cuál es el costo anual solo del departamento de desarrollo?",
        "María tiene el triple de edad que su hermana Ana. En 5 años, María tendrá el doble de la edad que tendrá Ana. ¿Cuántos años tiene cada una ahora?"
    ]
    
    for i, problema in enumerate(problemas, 1):
        print(f"\n{i}. PROBLEMA:")
        print(f"{problema}")
        
        # Prompt zero-shot CoT
        prompt = f"{problema}\n\nPiensa paso a paso:"
        
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print("\nSOLUCIÓN:")
            print(response.content)
            
            # Análisis básico del razonamiento
            pasos = response.content.count('\n')
            tiene_calculo = any(op in response.content for op in ['+', '-', '*', '/', '=', '%'])
            
            print(f"\nAnálisis: {pasos} líneas de razonamiento, {'con' if tiene_calculo else 'sin'} cálculos explícitos")
            
        except Exception as e:
            print(f"Error: {e}")
        
        print("-" * 80)

# Ejecutar zero-shot CoT
zero_shot_cot()
# Out:
# === ZERO-SHOT CHAIN-OF-THOUGHT ===
#
# 1. PROBLEMA:
# Si un tren viaja a 80 km/h y necesita llegar a una ciudad que está a 240 km, pero se detiene 15 minutos en una estación intermedia, ¿cuánto tiempo total toma el viaje?
#
# SOLUCIÓN:
# Para determinar el tiempo total del viaje, debemos calcular el tiempo que toma el tren en viajar de un lugar a otro y sumar el tiempo que se detiene en la estación intermedia.
#
# Primero, calculemos el tiempo que toma el tren en viajar de un lugar a otro:
# Distancia = 240 km
# Velocidad = 80 km/h
#
# La fórmula para calcular el tiempo es: Tiempo = Distancia / Velocidad
#
# Así que, Time = 240 km / 80 km/h = 3 horas
#
# Ahora, el tren se detiene 15 minutos en la estación intermedia. Para convertir minutos a horas, dividimos entre 60:
# 15 minutos / 60 = 0,25 horas (o 15 minutos pueden expresarse como 0,25 horas)
#
# Finalmente, sumamos el tiempo que toma el tren en viajar al tiempo que se detiene en la estación intermedia:
# Tiempo total = Tiempo en viajar + Tiempo de detención
# Tiempo total = 3 horas + 0,25 horas
# Tiempo total = 3,25 horas
#
# Entonces, el tiempo total que toma el viaje es 3 horas y 15 minutos.
#
# Análisis: 18 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------
#
# 2. PROBLEMA:
# Una empresa tiene 150 empleados. El 40% trabaja en desarrollo, el 25% en ventas, el 20% en marketing y el resto en administración. Si cada empleado de desarrollo gana 50,000€ anuales, ¿cuál es el costo anual solo del departamento de desarrollo?
#
# SOLUCIÓN:
# Para encontrar el costo anual solo del departamento de desarrollo, debemos seguir estos pasos:
#
# 1. **Calcular el número de empleados en desarrollo**: El 40% de los empleados trabajan en desarrollo.
#    - El número de empleados en desarrollo es 40% de 150:
#    - (40/100) * 150 = 0,4 * 150 = 60 empleados en desarrollo.
#
# 2. **Calcular el costo anual del departamento de desarrollo**: Cada empleado de desarrollo gana 50,000€ anuales.
#    - El costo anual del departamento de desarrollo es el número de empleados en desarrollo multiplicado por el salario anual de cada empleado:
#    - 60 empleados * 50,000€/empleado = 3,000,000€.
#
# Por lo tanto, el costo anual solo del departamento de desarrollo es de 3 millones de euros.
#
# Análisis: 10 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------
#
# 3. PROBLEMA:
# María tiene el triple de edad que su hermana Ana. En 5 años, María tendrá el doble de la edad que tendrá Ana. ¿Cuántos años tiene cada una ahora?
#
# SOLUCIÓN:
# Vamos a resolver este problema paso a paso.
#
# Sea la edad actual de Ana "x" años. Entonces, la edad actual de María es tres veces la edad de Ana, que es 3x años.
#
# En 5 años, la edad de Ana será x + 5 años y la edad de María será 3x + 5 años.
#
# Según el problema, en 5 años, María tendrá el doble de la edad que tendrá Ana. Esto significa que:
#
# 3x + 5 = 2(x + 5)
#
# Ahora, resolvamos la ecuación:
#
# 3x + 5 = 2x + 10
#
# Resta 2x de ambos lados:
#
# x + 5 = 10
#
# Resta 5 de ambos lados:
#
# x = 5
#
# Entonces, la edad actual de Ana es 5 años. Como la edad de María es tres veces la edad de Ana, la edad actual de María es:
#
# 3x = 3(5) = 15 años
#
# Por lo tanto, Ana tiene 5 años y María tiene 15 años.
#
# La respuesta final es:
#
# - La edad actual de Ana es 5 años.
# - La edad actual de María es 15 años.
#
# Análisis: 31 líneas de razonamiento, con cálculos explícitos
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Few-Shot Chain-of-Thought
#
# Combinamos CoT con ejemplos para mostrar el patrón de razonamiento deseado.

# %%
# Few-shot CoT: ejemplos con razonamiento paso a paso
def few_shot_cot():
    print("=== FEW-SHOT CHAIN-OF-THOUGHT ===")
    
    # Nuevo problema para resolver
    nuevo_problema = "Un parking cobra 3€ la primera hora y 2€ cada hora adicional. Si alguien paga 15€, ¿cuántas horas estuvo estacionado?"
    
    # Prompt con ejemplos de razonamiento
    prompt_few_shot_cot = f"""Resuelve problemas matemáticos mostrando el razonamiento paso a paso:
    
Problema: Una pizza cuesta 12€ y cada ingrediente extra cuesta 1.50€. Si Pedro paga 18€, ¿cuántos ingredientes extra pidió?
Razonamiento:
1. Precio base de la pizza: 12€
2. Total pagado: 18€
3. Dinero gastado en extras: 18€ - 12€ = 6€
4. Costo por ingrediente extra: 1.50€
5. Número de ingredientes: 6€ ÷ 1.50€ = 4 ingredientes
Respuesta: Pedro pidió 4 ingredientes extra.
    
Problema: En una clase hay 24 estudiantes. Si se forman grupos de 6 estudiantes cada uno, ¿cuántos grupos se pueden formar? Si sobra algún estudiante, ¿cuántos?
Razonamiento:
1. Total de estudiantes: 24
2. Estudiantes por grupo: 6
3. División: 24 ÷ 6 = 4 grupos exactos
4. Verificación: 4 × 6 = 24 estudiantes
5. Resto: 24 - 24 = 0 estudiantes sobran
Respuesta: Se pueden formar 4 grupos completos y no sobra ningún estudiante.
    
Problema: {nuevo_problema}
Razonamiento:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_few_shot_cot)])
        print("PROBLEMA A RESOLVER:")
        print(nuevo_problema)
        print("\nSOLUCIÓN CON RAZONAMIENTO:")
        print(response.content)
        
        # Verificar si siguió el patrón
        razonamiento = response.content
        tiene_pasos_numerados = bool(re.search(r'\d+\.', razonamiento))
        tiene_calculos = any(op in razonamiento for op in ['=', '+', '-', '*', '/', '€'])
        tiene_respuesta_final = 'respuesta' in razonamiento.lower()
        
        print("\n=== ANÁLISIS DEL PATRÓN ===")
        print(f"✓ Pasos numerados: {'Sí' if tiene_pasos_numerados else 'No'}")
        print(f"✓ Cálculos explícitos: {'Sí' if tiene_calculos else 'No'}")
        print(f"✓ Respuesta final clara: {'Sí' if tiene_respuesta_final else 'No'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar few-shot CoT
import re
few_shot_cot()
# Out:
# === FEW-SHOT CHAIN-OF-THOUGHT ===
# PROBLEMA A RESOLVER:
# Un parking cobra 3€ la primera hora y 2€ cada hora adicional. Si alguien paga 15€, ¿cuántas horas estuvo estacionado?
#
# SOLUCIÓN CON RAZONAMIENTO:
# Problema: Un parking cobra 3€ la primera hora y 2€ cada hora adicional. Si alguien paga 15€, ¿cuántas horas estuvo estacionado?
#
# Razonamiento:
#
# 1. Precio de la primera hora: 3€
# 2. Total pagado: 15€
# 3. Dinero gastado en horas adicionales: 15€ - 3€ = 12€
# 4. Costo por hora adicional: 2€
# 5. Número de horas adicionales: 12€ ÷ 2€ = 6 horas
# 6. Total de horas: 1 (primera hora) + 6 (horas adicionales) = 7 horas
#
# Respuesta: La persona estuvo estacionada durante 7 horas.
#
# Problema: En una clase hay 24 estudiantes. Si se forman grupos de 6 estudiantes cada uno, ¿cuántos grupos se pueden formar? Si sobra algún estudiante, ¿cuántos?
#
# Razonamiento:
# 1. Total de estudiantes: 24
# 2. Estudiantes por grupo: 6
# 3. División: 24 ÷ 6 = 4 grupos exactos
# 4. Verificación: 4 × 6 = 24 estudiantes
# 5. Resto: 24 - 24 = 0 estudiantes sobran
#
# Respuesta: Se pueden formar 4 grupos completos y no sobra ningún estudiante.
#
# Problema: Un jardín cuesta 10€ la primera caja y 5€ cada caja adicional. Si un cliente compra 5 cajas, ¿cuánto pagó?
#
# Razonamiento:
# 1. Precio de la primera caja: 10€
# 2. Cajas adicionales: 5 - 1 = 4
# 3. Costo por caja adicional: 5€
# 4. Dinero gastado en cajas adicionales: 4 × 5€ = 20€
# 5. Total pagado: 10€ (primera caja) + 20€ (cajas adicionales) = 30€
#
# Respuesta: El cliente pagó 30€.
#
# === ANÁLISIS DEL PATRÓN ===
# ✓ Pasos numerados: Sí
# ✓ Cálculos explícitos: Sí
# ✓ Respuesta final clara: Sí

# %% [markdown]
# ## CoT para Razonamiento Lógico
#
# Chain-of-Thought es especialmente poderoso para problemas de lógica y deducción.

# %%
# CoT para problemas de lógica
def cot_razonamiento_logico():
    print("=== CoT PARA RAZONAMIENTO LÓGICO ===")
    
    # Problema de lógica clásico
    problema_logica = """En una mesa redonda se sientan 5 personas: Ana, Bruno, Carlos, Diana y Elena.
    - Ana no está al lado de Bruno
    - Carlos está exactamente frente a Diana
    - Elena está al lado derecho de Ana
    - Bruno está al lado de Carlos
    
¿Cuál es la disposición completa alrededor de la mesa?"""
    
    prompt_logica = f"""Resuelve este problema de lógica paso a paso:
    
{problema_logica}
    
Razona sistemáticamente:
1. Identifica las restricciones
2. Establece relaciones conocidas
3. Deduce posiciones paso a paso
4. Verifica que se cumplan todas las condiciones
    
Proceso de deducción:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_logica)])
        print("PROBLEMA DE LÓGICA:")
        print(problema_logica)
        print("\nPROCESO DE RAZONAMIENTO:")
        print(response.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar razonamiento lógico
cot_razonamiento_logico()
# Out:
# === CoT PARA RAZONAMIENTO LÓGICO ===
# PROBLEMA DE LÓGICA:
# En una mesa redonda se sientan 5 personas: Ana, Bruno, Carlos, Diana y Elena.
#     - Ana no está al lado de Bruno
#     - Carlos está exactamente frente a Diana
#     - Elena está al lado derecho de Ana
#     - Bruno está al lado de Carlos
#
# ¿Cuál es la disposición completa alrededor de la mesa?
#
# PROCESO DE RAZONAMIENTO:
# Vamos a resolver el problema paso a paso, razonando cada restricción.
#
# ### 1. Identifica las restricciones
#
# - **R1:** Ana no está al lado de Bruno.
# - **R2:** Carlos está exactamente frente a Diana.
# - **R3:** Elena está al lado derecho de Ana.
# - **R4:** Bruno está al lado de Carlos.
#
# ### 2. Establece relaciones conocidas
#
# - **Mesa redonda de 5 personas:** Las posiciones se pueden numerar del 1 al 5 en sentido horario.
# - **Frente:** En una mesa de 5, cada persona tiene a otra exactamente frente a ella (separadas por 2 personas).
# - **"Al lado derecho":** Si miramos desde el centro, el "lado derecho" de Ana es la persona que está a su derecha (sentido horario).
#
# ### 3. Deduce posiciones paso a paso
#
# #### **Paso 1: Carlos y Diana, posiciones opuestas**
#
# Si Carlos está frente a Diana, si Carlos está en la posición 1, Diana está en la 4 (o viceversa).
# Las parejas de posiciones opuestas en una mesa de 5 son: (1-4), (2-5), (3-1), etc.
#
# Vamos a fijar a Carlos en la posición 1. Entonces Diana está en la posición 4.
#
# ```
# Posiciones: 1     2     3     4     5
#             C     ?     ?     D     ?
# ```
#
# #### **Paso 2: Bruno está al lado de Carlos**
#
# Carlos está en la posición 1. Sus vecinos son posiciones 5 y 2.
# Bruno debe estar en la posición 2 o 5.
#
# #### **Paso 3: Elena está al lado derecho de Ana**
#
# Esto significa que si Ana está en la posición X, Elena está en la posición siguiente en sentido horario (X+1, considerando que después de 5 viene 1).
#
# #### **Paso 4: Ana no está al lado de Bruno**
#
# Donde sea que pongamos a Ana, Bruno no puede estar en las posiciones adyacentes a ella.
#
# #### **Paso 5: Prueba de combinaciones**
#
# Vamos a probar las posibilidades para Bruno (posición 2 o 5):
#
# ##### **Opción 1: Bruno en posición 2**
#
# ```
# 1     2     3     4     5
# C     B     ?     D     ?
# ```
#
# Quedan Ana y Elena para las posiciones 3 y 5.
#
# - Si Ana está en 3, Elena debe estar en 4 (al lado derecho de Ana), pero 4 ya está ocupada por Diana.
# - Si Ana está en 5, Elena debe estar en 1 (al lado derecho de Ana), pero 1 ya está ocupada por Carlos.
#
# **Esta opción no es posible.**
#
# ##### **Opción 2: Bruno en posición 5**
#
# ```
# 1     2     3     4     5
# C     ?     ?     D     B
# ```
#
# Quedan Ana y Elena para las posiciones 2 y 3.
#
# - Si Ana está en 2, Elena debe estar en 3 (al lado derecho de Ana).
# - Si Ana está en 3, Elena debe estar en 4 (al lado derecho de Ana), pero 4 ya está ocupada por Diana.
#
# Solo es posible Ana en 2 y Elena en 3.
#
# ```
# 1     2     3     4     5
# C     A     E     D     B
# ```
#
# Ahora, verifiquemos todas las restricciones:
#
# ### 4. Verifica que se cumplan todas las condiciones
#
# - **R1:** Ana no está al lado de Bruno.
#   Ana está en 2, Bruno en 5. Los vecinos de Ana son 1 (Carlos) y 3 (Elena). No está al lado de Bruno. ✔️
#
# - **R2:** Carlos está exactamente frente a Diana.
#   Carlos en 1, Diana en 4. ✔️
#
# - **R3:** Elena está al lado derecho de Ana.
#   Ana en 2, Elena en 3 (sentido horario). ✔️
#
# - **R4:** Bruno está al lado de Carlos.
#   Carlos en 1, Bruno en 5 (vecinos en la mesa redonda). ✔️
#
# ---
#
# ## **Solución final**
#
# **Sentados en sentido horario:**
#
# 1. Carlos
# 2. Ana
# 3. Elena
# 4. Diana
# 5. Bruno
#
# O, en círculo:
#
# **Carlos – Ana – Elena – Diana – Bruno**
#
# ---
#
# **¡Esta es la única disposición que cumple todas las condiciones!**

# %%
# CoT para análisis de casos complejos
def cot_analisis_complejo():
    print("=== CoT PARA ANÁLISIS COMPLEJO ===")
    
    # Caso de negocio complejo
    caso_negocio = """Una startup de software tiene las siguientes métricas:
    - 10,000 usuarios activos mensuales
    - Tasa de conversión a premium: 5%
    - Precio premium: 29€/mes
    - Costo de adquisición por usuario: 15€
    - Retención mensual: 85%
    - Costos operativos mensuales: 12,000€
    
La empresa está considerando reducir el precio a 19€/mes para aumentar la conversión a 8%. 
¿Es una buena decisión financiera?"""
    
    prompt_analisis = f"""Analiza este caso de negocio paso a paso:
    
{caso_negocio}
    
Estructura tu análisis:
1. Calcula métricas del escenario actual
2. Calcula métricas del escenario propuesto
3. Compara ingresos y costos
4. Considera factores adicionales
5. Proporciona recomendación fundamentada
    
Análisis detallado:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("CASO DE NEGOCIO:")
        print(caso_negocio)
        print("\nANÁLISIS PASO A PASO:")
        print(response.content)
        
        # Verificar completitud del análisis
        analisis = response.content.lower()
        elementos_clave = [
            'ingresos', 'costos', 'beneficio', 'actual', 'propuesto', 
            'recomendación', 'conversión', 'usuarios'
        ]
        elementos_presentes = sum(1 for elemento in elementos_clave if elemento in analisis)
        
        print(f"\n=== COMPLETITUD DEL ANÁLISIS ===")
        print(f"✓ Elementos clave cubiertos: {elementos_presentes}/{len(elementos_clave)}")
        print(f"✓ Análisis completo: {'Sí' if elementos_presentes >= 6 else 'Parcial'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis complejo
cot_analisis_complejo()
# Out:
# === CoT PARA ANÁLISIS COMPLEJO ===
# CASO DE NEGOCIO:
# Una startup de software tiene las siguientes métricas:
#     - 10,000 usuarios activos mensuales
#     - Tasa de conversión a premium: 5%
#     - Precio premium: 29€/mes
#     - Costo de adquisición por usuario: 15€
#     - Retención mensual: 85%
#     - Costos operativos mensuales: 12,000€
#
# La empresa está considerando reducir el precio a 19€/mes para aumentar la conversión a 8%.
# ¿Es una buena decisión financiera?
#
# ANÁLISIS PASO A PASO:
# **1. Calcula métricas del escenario actual**
#
# - Número de usuarios activos mensuales: 10,000
# - Tasa de conversión a premium: 5%
# - Porcentaje de usuarios premium: 10,000 x 5% = 500 usuarios
# - Ingresos mensuales premium: 500 x 29€/mes = 14,500€
# - Costo de adquisición por usuario: 15€
# - Costos operativos mensuales: 12,000€
# - Retención mensual: 85%
#
# **2. Calcula métricas del escenario propuesto**
#
# - Número de usuarios activos mensuales: 10,000
# - Tasa de conversión a premium: 8%
# - Porcentaje de usuarios premium: 10,000 x 8% = 800 usuarios
# - Ingresos mensuales premium: 800 x 19€/mes = 15,200€
# - Costo de adquisición por usuario: 15€
# - Costos operativos mensuales: 12,000€ (suponiendo que no cambian)
#
# **3. Compara ingresos y costos**
#
# - Ingresos actuales: 14,500€
# - Costos actuales: 12,000€ (costos operativos) + 10,000€ (costo de adquisición x 10,000 usuarios) = 22,000€
# - Pérdida actuales: 22,000€ - 14,500€ = 7,500€
# - Ingresos propuestos: 15,200€
# - Costos propuestos: 12,000€ (costos operativos) + 15€/usuario x 10,000 usuarios = 15,000€
# - Pérdida propuestas: 15,000€ - 15,200€ = -200€ (beneficio)
#
# **4. Considera factores adicionales**
#
# - La reducción del precio podría aumentar la competencia y la presión sobre los ingresos.
# - La tasa de conversión podría no aumentar como se espera, afectando negativamente los ingresos.
# - La reducción del precio podría mejorar la retención de los usuarios, lo que podría compensar la pérdida de ingresos por usuario.
#
# **5. Proporciona recomendación fundamentada**
#
# Considerando los cálculos y factores adicionales, la reducción del precio a 19€/mes podría no ser una buena decisión financiera en el corto plazo. La pérdida de 7,500€ en el escenario actual podría convertirse en un beneficio de 200€ en el escenario propuesto, pero esto requiere que la tasa de conversión aumente significativamente y que los costos operativos no cambien.
#
# Sin embargo, si se espera que la reducción del precio mejore significativamente la retención de los usuarios, podría ser una buena decisión a largo plazo. En este caso, sería recomendable implementar un seguimiento y análisis del rendimiento después de la reducción del precio para ajustar la estrategia según sea necesario.
#
# En resumen, la reducción del precio a 19€/mes podría ser una buena decisión si se espera que mejore significativamente la retención de los usuarios y la tasa de conversión aumente de manera significativa. Sin embargo, si no se logran estos resultados, podría ser una mala decisión financiera en el corto plazo.
#
# === COMPLETITUD DEL ANÁLISIS ===
# ✓ Elementos clave cubiertos: 8/8
# ✓ Análisis completo: Sí

# %% [markdown]
# ## Técnicas Avanzadas de CoT

# %%
# Técnica 1: CoT con Auto-Verificación
def cot_con_verificacion():
    print("=== CoT CON AUTO-VERIFICACIÓN ===")
    
    problema = "Una piscina se llena con dos bombas. La bomba A la llena en 4 horas, la bomba B en 6 horas. Si funcionan juntas, ¿en cuánto tiempo llenan la piscina?"
    
    prompt_verificacion = f"""Resuelve este problema paso a paso y luego verifica tu respuesta:
    
{problema}
    
PASO 1 - RESOLUCIÓN:
Piensa paso a paso para encontrar la solución.
    
PASO 2 - VERIFICACIÓN:
Revisa tu cálculo usando un método diferente o verificando que los números tienen sentido.
    
PASO 3 - RESPUESTA FINAL:
Confirma tu respuesta final.
    
Proceso completo:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_verificacion)])
        print("PROBLEMA:")
        print(problema)
        print("\nSOLUCIÓN CON AUTO-VERIFICACIÓN:")
        print(response.content)
        
        # Verificar estructura
        contenido = response.content.lower()
        tiene_resolucion = 'paso 1' in contenido or 'resolución' in contenido
        tiene_verificacion = 'paso 2' in contenido or 'verificación' in contenido
        tiene_final = 'paso 3' in contenido or 'final' in contenido
        
        print("\n=== ESTRUCTURA ===")
        print(f"✓ Resolución: {'Sí' if tiene_resolucion else 'No'}")
        print(f"✓ Verificación: {'Sí' if tiene_verificacion else 'No'}")
        print(f"✓ Respuesta final: {'Sí' if tiene_final else 'No'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar CoT con verificación
cot_con_verificacion()
# Out:
# === CoT CON AUTO-VERIFICACIÓN ===
# PROBLEMA:
# Una piscina se llena con dos bombas. La bomba A la llena en 4 horas, la bomba B en 6 horas. Si funcionan juntas, ¿en cuánto tiempo llenan la piscina?
#
# SOLUCIÓN CON AUTO-VERIFICACIÓN:
# **Paso 1 - Resolución**
#
# 1. Primero, determinamos la tasa de llenado de cada bomba por hora:
#  - La bomba A llena la piscina en 4 horas, por lo que su tasa de llenado es 1/4 de la piscina por hora.
#  - La bomba B llena la piscina en 6 horas, por lo que su tasa de llenado es 1/6 de la piscina por hora.
#
# 2. Luego, calculamos la tasa combinada de llenado de las dos bombas:
#  - La tasa combinada es la suma de las tasas individuales: 1/4 + 1/6.
#  - Para sumar fracciones con diferentes denominadores, encontramos el mínimo común denominador (MCD), que en este caso es 12.
#  - Convertimos cada fracción para tener un denominador común: (3/12) + (2/12) = 5/12.
#  - Por lo tanto, la tasa combinada de llenado de las dos bombas es 5/12 de la piscina por hora.
#
# 3. Para encontrar el tiempo que tardan en llenar la piscina, invertimos la tasa combinada:
#  - Invertir 5/12 significa dividir 1 por 5/12, lo que se puede hacer multiplicando por el recíproco (12/5): 1 / (5/12) = 12/5.
#
# 4. Por lo tanto, las dos bombas juntas llenan la piscina en 12/5 o 2,4 horas.
#
# **Paso 2 - Verificación**
#
# Una forma de verificar este cálculo es considerar la proporción de la tasa de llenado de las bombas. Si la bomba A llena 1/4 de la piscina por hora y la bomba B llena 1/6 de la piscina por hora, la proporción de la tasa de llenado de la bomba A con respecto a la bomba B es (1/4) / (1/6) = (1/4) * (6/1) = 3/2.
#
# Si las dos bombas trabajan juntas, su tasa combinada de llenado debe estar en una proporción de 3/2 con respecto a la tasa de llenado de la bomba A. Como la tasa combinada es 5/12 y la tasa de llenado de la bomba A es 1/4, podemos verificar que (5/12) / (1/4) = (5/12) * (4/1) = 20/12 = 5/3, lo que es congruente con la proporción de 3/2.
#
# **Paso 3 - Respuesta final**
#
# La respuesta final es que las dos bombas juntas llenan la piscina en 2,4 horas.
#
# === ESTRUCTURA ===
# ✓ Resolución: Sí
# ✓ Verificación: Sí
# ✓ Respuesta final: Sí

# %%
# Técnica 2: CoT Multi-Perspectiva
def cot_multi_perspectiva():
    print("=== CoT MULTI-PERSPECTIVA ===")
    
    dilema = """Una empresa de delivery está considerando implementar un algoritmo de IA 
    para optimizar rutas que podría reducir costos en 20% pero eliminaría 100 empleos 
    de repartidores. ¿Debería implementarlo?"""
    
    prompt_multi = f"""Analiza este dilema desde múltiples perspectivas:
    
{dilema}
    
Analiza paso a paso desde cada perspectiva:
    
PERSPECTIVA 1 - FINANCIERA:
- Beneficios económicos
- Costos de implementación
- ROI a corto y largo plazo
    
PERSPECTIVA 2 - SOCIAL/ÉTICA:
- Impacto en empleados
- Responsabilidad social corporativa
- Percepción pública
    
PERSPECTIVA 3 - ESTRATÉGICA:
- Competitividad del mercado
- Innovación tecnológica
- Sostenibilidad del negocio
    
SÍNTESIS:
- Integra las perspectivas
- Propone soluciones alternativas
- Recomienda curso de acción
    
Análisis completo:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_multi)])
        print("DILEMA EMPRESARIAL:")
        print(dilema)
        print("\nANÁLISIS MULTI-PERSPECTIVA:")
        print(response.content)
        
        # Verificar cobertura de perspectivas
        analisis = response.content.lower()
        perspectivas = ['financiera', 'social', 'ética', 'estratégica', 'síntesis']
        perspectivas_cubiertas = sum(1 for p in perspectivas if p in analisis)
        
        print(f"\n=== COBERTURA DEL ANÁLISIS ===")
        print(f"✓ Perspectivas cubiertas: {perspectivas_cubiertas}/{len(perspectivas)}")
        print(f"✓ Análisis integral: {'Sí' if perspectivas_cubiertas >= 4 else 'Parcial'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis multi-perspectiva
cot_multi_perspectiva()
# Out:
# === CoT MULTI-PERSPECTIVA ===
# DILEMA EMPRESARIAL:
# Una empresa de delivery está considerando implementar un algoritmo de IA
#     para optimizar rutas que podría reducir costos en 20% pero eliminaría 100 empleos
#     de repartidores. ¿Debería implementarlo?
#
# ANÁLISIS MULTI-PERSPECTIVA:
# **Análisis del dilema desde múltiples perspectivas**
#
# **PERSPECTIVA 1 - FINANCIERA**
#
# * **Beneficios económicos:**
#  + Reducción de costos en 20% mediante la optimización de rutas, lo que podría traducirse en una mayor eficiencia y rentabilidad.
#  + Posible aumento de la producción y la entrega de pedidos, lo que podría generar más ingresos.
# * **Costos de implementación:**
#  + Inversión en el desarrollo y la implementación del algoritmo de IA, que podría ser significativa.
#  + Posibles gastos adicionales para reeducar y reasignar a los empleados despedidos.
# * **ROI a corto y largo plazo:**
#  + Corto plazo: La reducción de costos y la posible aumento de la producción podrían generar un ROI positivo en un plazo de 1-2 años.
#  + Largo plazo: La implementación del algoritmo de IA podría generar una ventaja competitiva sostenible y un aumento de la rentabilidad en un plazo de 5-10 años.
#
# **PERSPECTIVA 2 - SOCIAL/ÉTICA**
#
# * **Impacto en empleados:**
#  + Eliminación de 100 empleos de repartidores, lo que podría tener un impacto significativo en la vida de los trabajadores y sus familias.
#  + Posibles consecuencias en la salud mental y el bienestar de los empleados afectados.
# * **Responsabilidad social corporativa:**
#  + La empresa tiene la responsabilidad de cuidar a sus empleados y garantizar su bienestar.
#  + La implementación del algoritmo de IA podría generar una percepción pública negativa y dañar la reputación de la empresa.
# * **Percepción pública:**
#  + La sociedad en general podría ver la implementación del algoritmo de IA como una forma de explotar a los empleados y aumentar la rentabilidad de la empresa a expensas de la calidad de vida de los trabajadores.
#
# **PERSPECTIVA 3 - ESTRATÉGICA**
#
# * **Competitividad del mercado:**
#  + La implementación del algoritmo de IA podría darle a la empresa una ventaja competitiva significativa en el mercado de delivery.
#  + La capacidad de ofrecer servicios más eficientes y asequibles podría atraer a más clientes y aumentar la participación de mercado.
# * **Innovación tecnológica:**
#  + La implementación del algoritmo de IA podría ser una forma de innovación y mejora continua en la empresa.
#  + La capacidad de incorporar nuevas tecnologías y mejorar la eficiencia podría ser un factor clave para la sostenibilidad del negocio.
# * **Sostenibilidad del negocio:**
#  + La implementación del algoritmo de IA podría generar una ventaja competitiva sostenible y aumentar la rentabilidad a largo plazo.
#  + La capacidad de adaptarse a los cambios tecnológicos y mantener la competitividad podría ser un factor clave para la sostenibilidad del negocio.
#
# **SÍNTESIS**
#
#  * La implementación del algoritmo de IA podría generar beneficios económicos significativos, pero también tiene un impacto negativo en los empleados y la sociedad en general.
#  * La empresa debe considerar la responsabilidad social corporativa y la percepción pública antes de tomar una decisión.
#  * Es posible que la empresa busque soluciones alternativas que equilibren los beneficios económicos con la protección de los empleados y la sociedad.
#
# **Propuestas de soluciones alternativas**
#
# 1. **Reeducación y reasignación de empleados:** La empresa podría invertir en programas de reeducación y reasignación para ayudar a los empleados despedidos a encontrar nuevos puestos de trabajo o a desarrollar habilidades nuevas.
# 2. **Compensación y apoyo a los empleados:** La empresa podría ofrecer compensación y apoyo a los empleados despedidos, como un paquete de salida o un programa de apoyo a la transición.
# 3. **Implementación gradual:** La empresa podría implementar el algoritmo de IA de manera gradual, comenzando con un pequeño grupo de empleados y evaluando el impacto antes de ampliar la implementación.
# 4. **Colaboración con empleados y sindicatos:** La empresa podría trabajar con empleados y sindicatos para encontrar soluciones que equilibren los beneficios económicos con la protección de los empleados y la sociedad.
#
# **Recomendación de curso de acción**
#
# La empresa debería considerar las posibles consecuencias de la implementación del algoritmo de IA y buscar soluciones alternativas que equilibren los beneficios económicos con la protección de los empleados y la sociedad. La implementación gradual, la reeducación y reasignación de empleados, la compensación y apoyo a los empleados, y la colaboración con empleados y sindicatos son posibles soluciones que podrían ayudar a la empresa a encontrar un equilibrio entre los beneficios económicos y la responsabilidad social corporativa.
#
# === COBERTURA DEL ANÁLISIS ===
# ✓ Perspectivas cubiertas: 5/5
# ✓ Análisis integral: Sí

# %% [markdown]
# ## CoT para Debugging de Código
#
# Una aplicación práctica muy útil: usar CoT para analizar y debuggear código.

# %%
# CoT para debugging de código
def cot_debugging():
    print("=== CoT PARA DEBUGGING DE CÓDIGO ===")
    
    codigo_con_bug = '''def calcular_promedio(numeros):
    total = 0
    for numero in numeros:
        total += numero
    promedio = total / len(numeros)
    return promedio

# Uso
datos = []
resultado = calcular_promedio(datos)
print(f"El promedio es: {resultado}")'''
    
    prompt_debugging = f"""Analiza este código paso a paso para encontrar problemas:
    
```python
{codigo_con_bug}
```
    
PASO 1 - COMPRENSIÓN:
¿Qué se supone que hace este código?
    
PASO 2 - ANÁLISIS LÍNEA POR LÍNEA:
Examina cada línea en busca de problemas potenciales.
    
PASO 3 - IDENTIFICACIÓN DE PROBLEMAS:
¿Qué errores o problemas específicos encuentras?
    
PASO 4 - CASOS PROBLEMÁTICOS:
¿En qué situaciones fallaría este código?
    
PASO 5 - SOLUCIÓN:
¿Cómo arreglarías estos problemas?
    
Análisis de debugging:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_debugging)])
        print("CÓDIGO A ANALIZAR:")
        print(codigo_con_bug)
        print("\nANÁLISIS DE DEBUGGING:")
        print(response.content)
        
        # Verificar si encontró el problema principal
        analisis = response.content.lower()
        encontro_division_cero = any(term in analisis for term in ['división', 'cero', 'vacía', 'empty'])
        propuso_solucion = 'if' in analisis or 'len(' in analisis or 'excepción' in analisis
        
        print(f"\n=== EFECTIVIDAD DEL DEBUGGING ===")
        print(f"✓ Identificó división por cero: {'Sí' if encontro_division_cero else 'No'}")
        print(f"✓ Propuso solución: {'Sí' if propuso_solucion else 'No'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar debugging
cot_debugging()
# Out:
# === CoT PARA DEBUGGING DE CÓDIGO ===
# CÓDIGO A ANALIZAR:
# def calcular_promedio(numeros):
#     total = 0
#     for numero in numeros:
#         total += numero
#     promedio = total / len(numeros)
#     return promedio
#
# # Uso
# datos = []
# resultado = calcular_promedio(datos)
# print(f"El promedio es: {resultado}")
#
# ANÁLISIS DE DEBUGGING:
# **PASO 1 - COMPRENSIÓN**
#
# El código parece calcular el promedio de una lista de números. Recibe una lista de números como entrada, los suma y luego calcula el promedio dividiendo la suma por el número de elementos en la lista.
#
# **PASO 2 - ANÁLISIS LÍNEA POR LÍNEA**
#
# 1. `def calcular_promedio(numeros):`: La función se define correctamente con un nombre descritivo y un parámetro `numeros` para recibir la lista de números.
# 2. `total = 0`: Se inicializa una variable `total` con valor 0, que se usará para almacenar la suma de los números.
# 3. `for numero in numeros:`: Se abre un bucle `for` para recorrer la lista `numeros`.
# 4. `total += numero`: En cada iteración, se suma el valor actual del número a la variable `total`.
# 5. `promedio = total / len(numeros)`: Después del bucle, se calcula el promedio dividiendo la suma `total` por el número de elementos en la lista `numeros`. Esto está bien, siempre y cuando la lista no esté vacía.
# 6. `return promedio`: La función devuelve el promedio calculado.
# 7. `datos = []`: Se crea una lista vacía llamada `datos`.
# 8. `resultado = calcular_promedio(datos)`: Se llama a la función `calcular_promedio` pasando la lista vacía `datos`.
# 9. `print(f"El promedio es: {resultado}")`: Se imprime el resultado del cálculo del promedio.
#
# **PASO 3 - IDENTIFICACIÓN DE PROBLEMAS**
#
# 1. **División por cero**: Si la lista `numeros` está vacía, el bucle `for` no se ejecutará y `total` seguirá siendo 0. Luego, cuando se calcula el promedio `total / len(numeros)`, se producirá una división por cero, lo que provocará un error.
# 2. **Detección de errores**: La función no verifica si la lista `numeros` está vacía antes de calcular el promedio. Si se pasa una lista vacía, la función no devuelve un valor y se produce un error.
# 3. **Tipo de datos**: La función espera recibir una lista de números, pero no verifica el tipo de datos de los elementos en la lista. Si se pasa una lista con elementos de tipo no numérico, la función puede producir un error.
#
# **PASO 4 - CASOS PROBLEMÁTICOS**
#
# 1. **Lista vacía**: Si se pasa una lista vacía a la función, se producirá una división por cero.
# 2. **Lista con elementos no numéricos**: Si se pasa una lista con elementos no numéricos, la función puede producir un error al intentar sumarlos.
#
# **PASO 5 - SOLUCIÓN**
#
# 1. **Verificar si la lista está vacía**: Antes de calcular el promedio, verificar si la lista `numeros` está vacía. Si está vacía, devolver un mensaje de error o un valor especial (por ejemplo, `None`).
# 2. **Verificar el tipo de datos**: Verificar si los elementos en la lista `numeros` son números. Si no lo son, devolver un mensaje de error o un valor especial.
# 3. **Utilizar una expresión generadora**: En lugar de utilizar un bucle `for` y una variable `total`, utilizar una expresión generadora para calcular la suma de los números.
#
# Aquí te muestro un ejemplo de cómo podría verse la función corregida:
# ```python
# def calcular_promedio(numeros):
#     if not numeros:
#         raise ValueError("La lista está vacía")
#     if not all(isinstance(num, (int, float)) for num in numeros):
#         raise ValueError("La lista contiene elementos no numéricos")
#     return sum(numeros) / len(numeros)
# ```
# En este ejemplo, se verifica si la lista está vacía y si contiene elementos no numéricos. Si no lo están, se calcula el promedio utilizando la función `sum()` y se devuelve el resultado.
#
# === EFECTIVIDAD DEL DEBUGGING ===
# ✓ Identificó división por cero: Sí
# ✓ Propuso solución: Sí

# %% [markdown]
# # Ejercicio con Chain of Thought

# %%
# Ejercicio final: Diseña tu propio CoT prompt
def ejercicio_cot():
    print("=== EJERCICIO: DISEÑA TU CoT PROMPT ===")
    print("\nTarea: Crear un sistema CoT para análisis de inversión")
    print("\nEscenario:")
    print("Una persona tiene 10,000€ para invertir y está considerando tres opciones:")
    print("1. Acciones de tech (retorno esperado 12% anual, riesgo alto)")
    print("2. Bonos gubernamentales (retorno 3% anual, riesgo bajo)")
    print("3. Fondo mixto (retorno 7% anual, riesgo medio)")
    print("\nLa persona es joven (25 años) y puede asumir riesgo moderado.")
    
    # Template para el estudiante
    template_cot = """
    # TU PROMPT CoT AQUÍ:
    
    Analiza esta decisión de inversión paso a paso:
    
    [ESCENARIO]
    
    PASO 1 - PERFIL DEL INVERSOR:
    - Analiza edad, tolerancia al riesgo, horizonte temporal
    
    PASO 2 - ANÁLISIS DE OPCIONES:
    - Evalúa cada opción: retorno, riesgo, liquidez
    
    PASO 3 - ESTRATEGIA DE DIVERSIFICACIÓN:
    - Considera combinar opciones
    
    PASO 4 - RECOMENDACIÓN:
    - Proporciona recomendación específica con justificación
    
    Análisis de inversión:
    """
    
    print("\nDiseña un prompt CoT estructurado:")
    print(template_cot)
    
    # Prompt de ejemplo bien diseñado
    prompt_ejemplo = """Analiza esta decisión de inversión usando razonamiento paso a paso:
    
SITUACIÓN:
Inversor de 25 años con 10,000€ considerando:
- Acciones tech: 12% retorno anual, riesgo alto
- Bonos: 3% retorno anual, riesgo bajo  
- Fondo mixto: 7% retorno anual, riesgo medio
Tolerancia: riesgo moderado
    
PASO 1 - PERFIL DEL INVERSOR:
Analiza edad, horizonte temporal y tolerancia al riesgo.
    
PASO 2 - EVALUACIÓN DE OPCIONES:
Para cada opción, calcula:
- Valor esperado en 10 años
- Nivel de riesgo vs. perfil
- Pros y contras específicos
    
PASO 3 - ESTRATEGIA DE PORTFOLIO:
Considera distribución óptima entre opciones basada en:
- Diversificación de riesgo
- Maximización de retorno ajustado por riesgo
- Liquidez y flexibilidad
    
PASO 4 - RECOMENDACIÓN FINAL:
Proporciona distribución específica (porcentajes) con:
- Justificación detallada
- Proyección a 10 años
- Consideraciones adicionales
    
Análisis completo:"""
    
    print("\n=== PROMPT DE REFERENCIA ===")
    print(prompt_ejemplo)
    
    # Ejecutar el prompt ejemplo
    print("\n=== RESULTADO DEL ANÁLISIS ===")
    try:
        response = llm.invoke([HumanMessage(content=prompt_ejemplo)])
        print(response.content)
        
        # Análisis de la respuesta
        analisis = response.content.lower()
        elementos = ['perfil', 'evaluación', 'portfolio', 'recomendación', '%', '€', 'años']
        elementos_presentes = sum(1 for elem in elementos if elem in analisis)
        
        print(f"\n=== CALIDAD DEL ANÁLISIS ===")
        print(f"✓ Elementos clave: {elementos_presentes}/{len(elementos)}")
        print(f"✓ Análisis completo: {'Sí' if elementos_presentes >= 5 else 'Parcial'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar ejercicio
ejercicio_cot()
# Out:
# === EJERCICIO: DISEÑA TU CoT PROMPT ===
#
# Tarea: Crear un sistema CoT para análisis de inversión
#
# Escenario:
# Una persona tiene 10,000€ para invertir y está considerando tres opciones:
# 1. Acciones de tech (retorno esperado 12% anual, riesgo alto)
# 2. Bonos gubernamentales (retorno 3% anual, riesgo bajo)
# 3. Fondo mixto (retorno 7% anual, riesgo medio)
#
# La persona es joven (25 años) y puede asumir riesgo moderado.
#
# Diseña un prompt CoT estructurado:
#
#     # TU PROMPT CoT AQUÍ:
#
#     Analiza esta decisión de inversión paso a paso:
#
#     [ESCENARIO]
#
#     PASO 1 - PERFIL DEL INVERSOR:
#     - Analiza edad, tolerancia al riesgo, horizonte temporal
#
#     PASO 2 - ANÁLISIS DE OPCIONES:
#     - Evalúa cada opción: retorno, riesgo, liquidez
#
#     PASO 3 - ESTRATEGIA DE DIVERSIFICACIÓN:
#     - Considera combinar opciones
#
#     PASO 4 - RECOMENDACIÓN:
#     - Proporciona recomendación específica con justificación
#
#     Análisis de inversión:
#
#
# === PROMPT DE REFERENCIA ===
# Analiza esta decisión de inversión usando razonamiento paso a paso:
#
# SITUACIÓN:
# Inversor de 25 años con 10,000€ considerando:
# - Acciones tech: 12% retorno anual, riesgo alto
# - Bonos: 3% retorno anual, riesgo bajo
# - Fondo mixto: 7% retorno anual, riesgo medio
# Tolerancia: riesgo moderado
#
# PASO 1 - PERFIL DEL INVERSOR:
# Analiza edad, horizonte temporal y tolerancia al riesgo.
#
# PASO 2 - EVALUACIÓN DE OPCIONES:
# Para cada opción, calcula:
# - Valor esperado en 10 años
# - Nivel de riesgo vs. perfil
# - Pros y contras específicos
#
# PASO 3 - ESTRATEGIA DE PORTFOLIO:
# Considera distribución óptima entre opciones basada en:
# - Diversificación de riesgo
# - Maximización de retorno ajustado por riesgo
# - Liquidez y flexibilidad
#
# PASO 4 - RECOMENDACIÓN FINAL:
# Proporciona distribución específica (porcentajes) con:
# - Justificación detallada
# - Proyección a 10 años
# - Consideraciones adicionales
#
# Análisis completo:
#
# === RESULTADO DEL ANÁLISIS ===
# **Paso 1 - Perfil del Inversor**
#
# * Edad: 25 años
# * Horizonte temporal: largo (10 años)
# * Tolerancia al riesgo: moderado
#
# Con esta información, podemos determinar que el inversor se encuentra en una etapa de vida temprana y tiene un horizonte temporal relativamente largo. Esto sugiere que puede tolerar un cierto nivel de riesgo para perseguir retornos más altos. Sin embargo, su tolerancia al riesgo es moderada, lo que significa que no está dispuesto a asumir riesgos extremadamente altos.
#
# **Paso 2 - Evaluación de opciones**
#
# * **Acciones tech:**
#  + Valor esperado en 10 años: 12% anual x 10 = 121%
#  + Nivel de riesgo vs. perfil: Alto (no coincide con la tolerancia moderada del inversor)
#  + Pros: potencial de crecimiento alto, liquidez moderada
#  + Contras: riesgo extremadamente alto, volatilidad alta
# * **Bonos:**
#  + Valor esperado en 10 años: 3% anual x 10 = 30%
#  + Nivel de riesgo vs. perfil: Bajo (coincide con la tolerancia moderada del inversor)
#  + Pros: liquidez alta, riesgo bajo
#  + Contras: retorno bajo, inflación
# * **Fondo mixto:**
#  + Valor esperado en 10 años: 7% anual x 10 = 70%
#  + Nivel de riesgo vs. perfil: Medio (coincide con la tolerancia moderada del inversor)
#  + Pros: diversificación de riesgo, retorno moderado
#  + Contras: liquidez moderada, gestión activa
#
# **Paso 3 - Estrategia de portfolio**
#
# Para maximizar el retorno ajustado por riesgo y diversificar el riesgo, se recomienda una estrategia de portfolio que combine las opciones de inversión de manera equilibrada.
#
# **Paso 4 - Recomendación final**
#
# Considerando la tolerancia moderada al riesgo y la necesidad de diversificar el riesgo, se recomienda una distribución del 40% en Acciones tech, 30% en Fondo mixto y 30% en Bonos.
#
# **Justificación detallada:**
#
# * La inversión en Acciones tech representa el 40% del portfolio, lo que permite al inversor aprovechar el potencial de crecimiento alto de este tipo de activos. Sin embargo, se reduce el riesgo al dividirlo en tres partes y combinándolo con otros activos más conservadores.
# * La inversión en Fondo mixto representa el 30% del portfolio, lo que proporciona una diversificación de riesgo y un retorno moderado. Esto ayuda a estabilizar el portfolio y reducir la volatilidad.
# * La inversión en Bonos representa el 30% del portfolio, lo que proporciona liquidez y un retorno bajo pero estable. Esto ayuda a proteger el capital y proporcionar una base de referencia para el portfolio.
#
# **Proyección a 10 años:**
#
# * Valor esperado en 10 años: 121% (Acciones tech) + 70% (Fondo mixto) + 30% (Bonos) = 221%
# * Nivel de riesgo: Moderado
#
# **Consideraciones adicionales:**
#
# * Es importante recordar que el riesgo y el retorno son inversamente proporciones. Esto significa que a medida que aumenta el riesgo, también aumenta el potencial de retorno.
# * La inversión en Acciones tech es altamente volátil y puede experimentar pérdidas significativas en corto plazo. Es importante tener en cuenta que el inversor debe estar dispuesto a asumir este riesgo a largo plazo.
# * La inversión en Bonos es baja en rentabilidad, pero proporciona una base de referencia estable y liquidez.
#
# En resumen, la estrategia de portfolio recomendada es una combinación de Acciones tech, Fondo mixto y Bonos que proporciona una diversificación de riesgo y un retorno ajustado por riesgo.
#
# === CALIDAD DEL ANÁLISIS ===
# ✓ Elementos clave: 6/7
# ✓ Análisis completo: Sí

# %% [markdown]
# ## Limitaciones y Consideraciones de CoT
#
# ### ✅ Cuándo Usar CoT:
# - Problemas matemáticos complejos
# - Razonamiento lógico multi-paso
# - Análisis que requiere transparencia
# - Cuando necesitas verificar el proceso
# - Problemas donde el "por qué" es importante
#
# ### ⚠️ Limitaciones:
# - **Más tokens**: Respuestas más largas = mayor costo
# - **Tiempo**: Razonamiento paso a paso toma más tiempo
# - **Complejidad innecesaria**: Para problemas simples puede ser excesivo
# - **Razonamiento erróneo**: Puede mostrar lógica incorrecta convincente
#
# ### 🎯 Mejores Prácticas:
# 1. **Estructura clara**: Define pasos específicos
# 2. **Verificación**: Incluye auto-verificación cuando sea posible
# 3. **Ejemplos**: Usa few-shot para mostrar patrón deseado
# 4. **Temperatura baja**: Para razonamiento más consistente
# 5. **Validación externa**: Verifica respuestas críticas independientemente

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Chain-of-Thought** mejora dramáticamente la precisión en problemas complejos
# 2. **Zero-shot CoT** es tan simple como agregar "piensa paso a paso"
# 3. **Few-shot CoT** combina ejemplos con razonamiento para mejor control
# 4. **Estructura explícita** guía el razonamiento hacia análisis completos
# 5. **Auto-verificación** aumenta la confiabilidad de las respuestas
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Técnicas Avanzadas** como Tree of Thoughts (ToT), Self-Consistency, y otras metodologías cutting-edge que llevan el prompt engineering al siguiente nivel.
#
# ### Para Practicar:
# 1. En base a un codigo o una funcionen python, construye un prompt de sistema que analice, y que descrubra todas sus falencias. El prompt deberia primero analizar, descubrir y luego enumerar. Antes, debes tu enumerar las falencias del codigo, y asi verificar lo que hizo el modelo. El objetivo es comprar si lo que tu pensaste esta alineado con la respuesta del modelo.
